# %%
import konlpy
import os
print(konlpy.data.path)
# Out:
# ['/Users/nine1ll/konlpy_data', '/usr/share/konlpy_data', '/usr/local/share/konlpy_data', '/usr/lib/konlpy_data', '/usr/local/lib/konlpy_data', '/opt/anaconda3/lib/python3.12/site-packages/konlpy/data']

# %%
def get_path():
    path = konlpy.data.path
    if len(path) > 1:
        print(f"python version에 맞는 Path를 선택해야합니다.\n{path}")
    else:
        return path[0][:-5]

get_path()
# Out:
# python version에 맞는 Path를 선택해야합니다.
# ['/Users/nine1ll/konlpy_data', '/usr/share/konlpy_data', '/usr/local/share/konlpy_data', '/usr/lib/konlpy_data', '/usr/local/lib/konlpy_data', '/opt/anaconda3/lib/python3.12/site-packages/konlpy/data']

# %%
path = '/opt/anaconda3/lib/python3.12/site-packages/konlpy/data'
path[:-4]+"java"
# Out:
# '/opt/anaconda3/lib/python3.12/site-packages/konlpy/java'

# %%
os.chdir('/opt/anaconda3/lib/python3.12/site-packages/konlpy/java')
os.getcwd()
# Out:
# '/opt/anaconda3/lib/python3.12/site-packages/konlpy/java'

# %%
# !jar xvf open-korean-text-2.1.0.jar
# Out:
#   생성됨: META-INF/
#  증가됨: META-INF/MANIFEST.MF
#   생성됨: org/
#   생성됨: org/openkoreantext/
#   생성됨: org/openkoreantext/processor/
#   생성됨: org/openkoreantext/processor/tools/
#  증가됨: org/openkoreantext/processor/tools/UpdateAllTheExamples.class
#  증가됨: org/openkoreantext/processor/tools/CreateConjugationExamples.class
#  증가됨: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class
#  증가됨: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class
#  증가됨: org/openkoreantext/processor/tools/CreateParsingExamples.class
#  증가됨: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class
#  증가됨: org/openkoreantext/processor/tools/CreateConjugationExamples$.class
#  증가됨: org/openkoreantext/processor/tools/DeduplicateAndSortDictionaries$.class
#  증가됨: org/openkoreantext/processor/tools/CreateChunkParsingCandidates$.class
#  증가됨: org/openkoreantext/processor/tools/CreateChunkParsingCandidates.class
# ...

# %%
with open(f"/opt/anaconda3/lib/python3.12/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt") as f:
    data = f.read()
    
print(data[:50])
# Out:
# 가몽
# 가온
# 갓세븐
# 강새이
# 게임닉가
# 관우
# 귀여미
# 규
# 김유이
# 김준면
# 까까런
# 노컷
# 누너예
# 니노

# %%
import pandas as pd

df = pd.read_csv("/Users/nine1ll/BDP_termProject/Hadoop-Classification/data/crawling/ad-keyword/ad_keyword_merged.csv")
df.head()
# Out:
#     Keyword
# 0    망원동 술집
# 1    망원동 애견
# 2   망원동 분위기
# 3   망원동 데이트
# 4  망원동 애견동반

# %%
string = ""
for word in df['Keyword']:
    string += word+"\n"

# %%
print(string)
# Out:
# 망원동 술집
# 망원동 애견
# 망원동 분위기
# 망원동 데이트
# 망원동 애견동반
# 망원 강아지 술집
# 서울3대오뎅바
# 서울오뎅바
# 문래오뎅바
# 문래역맛집
# 문래술집
# 문래동맛집
# 문래동술집
# 문래동데이트
# 성수동핫플
# 성수양식
# 성수밥집
# 성수동피자
# 서울숲피자
# 수유역맛집
# 수유리맛집
# 수유고기집
# 수유밥집
# 수유역밥집
# 사당부추삼겹살
# 사당부추삼겹
# 사당역 삼겹살
# 남현동맛집
# 문정삼겹살
# 문정동고기집
# 장지역고기집
# 수유역이자카야
# 수유역가성비술집
# 수유리먹자골목맛집
# 수유이자카야토라
# 강북구이자카야
# 송파맛집
# 송파동맛집
# 잠실분식
# 송리단길 맛집
# 방화동카페
# 강서구카페
# 김포공항카페
# 공항시장역카페
# 공덕술집
# 공덕역술집
# 공덕와인바
# 공덕와인
# 마포 와인바
# 서울와인바추천
# 삼각지야장
# 용산야장
# 신용산야장
# 중식주점
# 중식이자카야
# 청담동이자카야
# 압구정루프탑
# 청담루프탑
# 압구정로데오역이자카야
# 압구정로데오루프탑
# 어린이대공원역맛집
# 건대밥집
# 뚝섬유원지맛집
# 서울숲밥집
# 건대데이트맛집
# 강남역맛집
# 강남역마라탕
# 강남역근처맛집
# 강남역주변맛집
# 강남역혼밥
# 선유도역맛집
# 당산역고기집
# 당산역삼겹살
# 선유도역삼겹살
# 양평동고기집
# 사당역샤브샤브
# 사당샤브샤브
# 사당역밥집
# 사당밥집
# 서초칼국수
# 강남곱창
# 강남곱창맛집
# 신사곱창
# 신사곱창맛집
# 가로수길곱창
# 가로수길곱창맛집
# 연남동 술집
# 연남동 술집 추천
# 연남동 술집 맛집
# 연남동 데이트 코스
# 동교동 술집
# 동교동 술집 추천
# 서울맛집
# 서울대입구역맛집
# 서울삼겹살
# 서울대입구역삼겹살
# 서울대입구역데이트
# 용산역맛집
# 용산고기집
# 용산역고기집
# 신용산고기집
# 신용산역고기집
# 서울대입구카페
# 봉천역카페
# 봉천동카페
# 서울대입구디저트
# 서울대입구붕어빵
# 성수동핫플
# 성수밥집
# 성수혼밥
# 성수덮밥
# ...

# %%
data += string

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n망원동 술집\n망원동 애견\n망원동 분위기\n망원동 데이트\n망원동 애견동반\n망원 강아지 술집\n서울3대오뎅바\n서울오뎅바\n문래오뎅바\n문래역맛집\n문래술집\n문래동맛집\n문래동술집\n문래동데이트\n성수동핫플\n성수양식\n성수밥집\n성수동피자\n서울숲피자\n수유역맛집\n수유리맛집\n수유고기집\n수유밥집\n수유역밥집\n사당부추삼겹살\n사당부추삼겹\n사당역 삼겹살\n남현동맛집\n문정삼겹살\n문정동고기집\n장지역고기집\n수유역이자카야\n수유역가성비술집\n수유리먹자골목맛집\n수유이자카야토라\n강북구이자카야\n송파맛집\n송파동맛집\n잠실분식\n송리단길 맛집\n방화동카페\n강서구카페\n김포공항카페\n공항시장역카페\n공덕술집\n공덕역술집\n공덕와인바\n공덕와인\n마포 와인바\n서울와인바추천\n삼각지야장\n용산야장\n신용산야장\n중식주점\n중식이자카야\n청담동이자카야\n압구정루프탑\n청담루프탑\n압구정로데오역이자카야\n압구정로데오루프탑\n어린이대공원역맛집\n건대밥집\n뚝섬유원지맛집\n서울숲밥집\n건대데이트맛집\n강남역맛집\n강남역마라탕\n강남역근처
# ...

# %%
with open("/opt/anaconda3/lib/python3.12/site-packages/konlpy/java/org/openkoreantext/processor/util/noun/names.txt", 'w') as f:
    f.write(data)
    
# !jar cvf open-korean-text-2.1.0.jar org
# Out:
# Manifest를 추가함
# 추가하는 중: org/(입력 = 0) (출력 = 0)(0%를 저장함)
# 추가하는 중: org/openkoreantext/(입력 = 0) (출력 = 0)(0%를 저장함)
# 추가하는 중: org/openkoreantext/processor/(입력 = 0) (출력 = 0)(0%를 저장함)
# 추가하는 중: org/openkoreantext/processor/tools/(입력 = 0) (출력 = 0)(0%를 저장함)
# 추가하는 중: org/openkoreantext/processor/tools/UpdateAllTheExamples.class(입력 = 1089) (출력 = 756)(30%를 감소함)
# 추가하는 중: org/openkoreantext/processor/tools/CreateConjugationExamples.class(입력 = 2367) (출력 = 1659)(29%를 감소함)
# 추가하는 중: org/openkoreantext/processor/tools/CreateConjugationExamples$ConjugationExample.class(입력 = 3569) (출력 = 1415)(60%를 감소함)
# 추가하는 중: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$PhraseExample.class(입력 = 3825) (출력 = 1443)(62%를 감소함)
# 추가하는 중: org/openkoreantext/processor/tools/CreateParsingExamples.class(입력 = 2427) (출력 = 1732)(28%를 감소함)
# 추가하는 중: org/openkoreantext/processor/tools/CreatePhraseExtractionExamples$.class(입력 = 5989) (출력 = 2472)(58%를 감소함)
# ...

# %%
import os
import re
import json
import time
import requests
import numpy as np 
import pandas as pd
from konlpy.tag import Okt
STOPWORDS_URL = "https://gist.githubusercontent.com/Nine1ll/3ec361da95ccd39101051ab57f86cf46/raw/a1a451421097fa9a93179cb1f1f0dc392f1f9da9/stopwords.txt"

okt = Okt()
drop_pos = ["Josa", "Punctuation", "Foreign", "KoreanParticle"]

def load_stopwords(filepath="Preprocessing/data/stopwords.txt", github_url=STOPWORDS_URL):
        stopwords = []
        if not os.path.exists(filepath):
            if github_url is None:
                raise ValueError("GitHub url이 제공되지 않았습니다.")
            
            # 다운로드하기
            response = requests.get(github_url)
            if response.status_code == 200:
                # 멀쩡하게 반응하면
                os.makedirs(os.path.dirname(filepath), exist_ok=True)
                with open(filepath, "w", encoding="utf-8") as f:
                    f.write(response.text)
                print(f"stopwords.txt를 {github_url}에서 {filepath}에 다운로드 했습니다. ")
            else:
                raise Exception(f"우와 에러다. HTTP Status: {response.status_code} 실패했습니다.")
        
        # 파일 읽어오기
        with open(filepath, "r", encoding="utf-8") as f:
            stopwords = [line.strip() for line in f.readlines()]
        
        return stopwords

def preprocessing(text, norm=False, stem=False):
    stopwords = load_stopwords()
    text = str(text)
    text = regex(text)
    words = okt.pos(text,norm=norm, stem=stem)
    words = [word for word, pos in words if pos not in drop_pos]
    words = [regex(word) for word in words if word not in stopwords and regex(word).strip()]
    
    return " ".join(words)


def regex(text):
    """
    거슬리는 데이터들 삭제
    정규 표현식 패턴 (인터넷 주소와 "© NAVER Corp" 삭제)
    한 단어 이하 삭제
    공백 제거
    시간 형식 삭제
    """
    print(text+"\n")
    pattern = r"(© NAVER Corp|https?://\S+|www\.\S+|m\.\S+|\S+\.\S+\.\S+)"
    cleaned_text = re.sub(pattern, "", text)
    cleaned_text = re.sub(r"\b\d{3,4}-\d{3,4}-\d{3,4}\b", "", cleaned_text)# 전화번호 형식 삭제 (예: 0507-1311, 010-1234-5678)
    cleaned_text = re.sub(r"\b\d+\b", "", cleaned_text)  # 숫자만 있는 부분을 제거
    cleaned_text = re.sub(r"\b\d{1,2}:\d{2}\b", "", cleaned_text) # 시간 형식 제외
    cleaned_text = re.sub(r"\b\w\b", "", cleaned_text) # 공백 제거
    cleaned_text = re.sub(r"\s+", " ", cleaned_text).strip() # 한 단어 이하 삭제


df = pd.read_csv("/Users/nine1ll/BDP_termProject/Hadoop-Classification/data/crawling/blog-review/양천_blog_review.csv")
print(df.shape)
df.dropna(inplace=True)
print(df.shape)
# Out:
# (221, 2)
# (220, 2)

# %%
print(df['Content'].isnull().sum())
# Out:
# 1

# %%
import chardet

# 파일 인코딩 확인
with open('/Users/nine1ll/BDP_termProject/Hadoop-Classification/data/crawling/blog-review/양천_blog_review.csv', 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    print(result)  # {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
import chardet

# 파일 인코딩 확인
with open('/Users/nine1ll/BDP_termProject/Hadoop-Classification/data/crawling/blog-review/강남_blog_review.csv', 'rb') as file:
    raw_data = file.read()
    result = chardet.detect(raw_data)
    print(result)  # {'encoding': 'EUC-KR', 'confidence': 0.99, 'language': 'Korean'}
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
df['content_pos'] = df['Content'].apply(lambda x: preprocessing(x))
# Out:
# 오목교 현대백화점 맛집 데이트코스 추천 '오목교곱창 목동본점' 영업시간 평일 16:00 - 22:40 22:00 라스트오더 토, 일 13:30 - 22:40 22:00 라스트오더 단체석, 네이버예약 가능⭕ 오목교곱창 목동본점 : 네이버 방문자리뷰 1,740 · 블로그리뷰 461 naver.me 오목교역 현대백화점 맛집 골목 거리에 있는 '오목교 곱창 목동본점' 을 방문했어요 웨이팅이 있는 맛집 답게 웨이팅석도 귀엽게 마련되어있더라구요! 저희는 5시 30분 이전에 들어가서 주말이지만 웨이팅은 하지 않고 들어갔어요! 곱창집이지만 넘모 힙한 곳 인테리어도 예뻐서 실제로도 커플분들이 많이 계시더라구요!! 와인을 파는 곱창집이 있다?? 진짜 요즘 곱창집은 달라도 뭐가 다른가봐요!! 곱창에.. 와인 한잔? 데이트 어떠신가요 대신 알려주세요!! 좌석도 널널하고 섹션이 살짝 분리되어있어서 데이트 뿐만 아니라 단체 회식하기에도 좋을 것 같아요!! 국내산 소곱창으로 회식시켜주는 회사라면... 회식... 매우 감사💜 네이버 참고 그리고 곳곳에 SBS 생방송투데이 방영이 써있던데 예약할때 보니까 통마늘 곱창 맛집편으로 2023년 8월에 따끈따끈하게 방영이 된 맛집이더라구요 특마늘곱창은 20인분 한정판매라니까 드시고싶으신 분은 일찍가시는걸 추천드려요!! Next image 그래서 저희도 통마늘 곱창을 먹어볼까 하다가 모듬곱창에 통마늘곱창+황소곱창+막창+대창+염통+벌집양까지 6가지 부위가 들어가는건 처음이라 모듬 2개로 먹기로했어요 모듬곱창 1인분 당 27,000원 30년 전통 곱창 장인의 레시피를 이어받은 원조 국내산 소곱창 전문점인데 이 가격이면 합리적이다 끄덕였습니다. 양이 좀 있는 커플이다 or 3인 이상이다 하면 커플, 패밀리, 로열 세트들도 있어서 할인 받아서 더 다양하게 메뉴를 즐길 수 있더라구요! 곱창을 시키기도 전에 미리 세팅을 해주시는데 순두부김치콩나물국이 나오더라구요 일반적으로 선짓국을 주는게 흔한데 오히려 깔끔한 김치콩나물국 나오니까 신선하더라구요! 와 근데 
# ...

# %%
from datetime import datetime

a = [{"error": "ee"}]

def error_file_name_extract():
    # 혹시 error나온 파일이 있으면 그날에 에러난 파일을 txt file로 저장
    if len(a) > 0:
        today = datetime.now().strftime("%Y%m%d")
        file_name = f"error_file_{today}.txt"
        
        with open(file_name, "w") as file:
            for error in a:
                # 딕셔너리의 각 값을 문자열로 변환 후 파일에 기록
                file.write(", ".join(map(str, error.items())) + "\n")

        print(f"파일 '{file_name}'에 저장되었습니다.")
    else:
        return None

# 함수 실행
error_file_name_extract()
# Out:
# 파일 'error_file_20241208.txt'에 저장되었습니다.

# %%
# error_file_name_extract()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 error_file_name_extract()
#
# Cell In[6], line 14, in error_file_name_extract()
#      11     with open(file_name, "w") as file:
#      12         for error in a:
# ---> 14             file.write(error.values() + "\n")  # 각 항목을 줄 단위로 저장
#      16     print(f"파일 '{file_name}'에 저장되었습니다.")
#      17 else:
#
# TypeError: unsupported operand type(s) for +: 'dict_values' and 'str'
